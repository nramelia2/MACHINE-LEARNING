# %% [markdown]
# <a href="https://colab.research.google.com/github/nramelia2/MACHINE-LEARNING/blob/main/UAS/RESNET.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### Sorry, for ResNet by using a lot of pictures my laptop is not strong enough. Can only run until Epoch 7/100 after 1 day 2 nights, then turns itself off. For the bottom part of the Epoch that is running, I took a Screen Shoot from Kaggle so that I can see the output picture.
# Reference : https://www.kaggle.com/code/abhilashawasthi/unet-with-simple-resnet-blocks
#
# Data : https://drive.google.com/drive/folders/1cGE7lcgeXiilYzr2qVhIq3H7q6q6xhot?usp=sharing

# %%
import os
import sys
import random
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
plt.style.use('seaborn-white')
import seaborn as sns
sns.set_style('white')

# %matplotlib inline

from sklearn.model_selection import train_test_split

from tqdm import tqdm_notebook

from skimage.io import imread, imshow
from skimage.transform import resize
from skimage.morphology import label

from keras.models import Model, load_model, save_model
from keras.layers import Input, Dropout, BatchNormalization, Activation, Add
from keras.layers.core import Lambda
from keras.layers.convolutional import Conv2D, Conv2DTranspose
from keras.layers.pooling import MaxPooling2D
from keras.layers import concatenate
from keras.callbacks import EarlyStopping, ModelCheckpoint, ReduceLROnPlateau
from keras import backend as K
from keras import optimizers
import tensorflow as tf
from tensorflow.keras.utils import img_to_array, img_to_array, load_img

import time
t_start = time.time()

# %%
version = 5
basic_name = f'Unet_resnet_v{version}'
save_model_name = basic_name + '.model'
submission_file = basic_name + '.csv'

print(save_model_name)
print(submission_file)
# Out:
# Unet_resnet_v5.model
# Unet_resnet_v5.csv

# %%
img_size_ori = 101
img_size_target = 101

def upsample(img):# not used
    if img_size_ori == img_size_target:
        return img
    return resize(img, (img_size_target, img_size_target), mode='constant', preserve_range=True)
    
def downsample(img):# not used
    if img_size_ori == img_size_target:
        return img
    return resize(img, (img_size_ori, img_size_ori), mode='constant', preserve_range=True)

# %%
# Loading of training/testing ids and depths
train_df = pd.read_csv("train.csv", index_col="id", usecols=[0])
depths_df = pd.read_csv("depths.csv", index_col="id")
train_df = train_df.join(depths_df)
test_df = depths_df[~depths_df.index.isin(train_df.index)]

len(train_df)
# Out:
# 4000

# %%
train_df["images"] = [np.array(load_img("train/images/{}.png".format(idx), grayscale=True)) / 255 for idx in tqdm_notebook(train_df.index)]
# Out:
# <ipython-input-9-91eea79f2520>:1: TqdmDeprecationWarning: This function will be removed in tqdm==5.0.0
# Please use `tqdm.notebook.tqdm` instead of `tqdm.tqdm_notebook`
#   train_df["images"] = [np.array(load_img("train/images/{}.png".format(idx), grayscale=True)) / 255 for idx in tqdm_notebook(train_df.index)]
# HBox(children=(HTML(value=''), FloatProgress(value=0.0, max=4000.0), HTML(value='')))
# C:\Users\ACER\anaconda3\lib\site-packages\keras\utils\image_utils.py:382: UserWarning: grayscale is deprecated. Please use color_mode = "grayscale"
#   warnings.warn('grayscale is deprecated. Please use '

# %%
train_df["masks"] = [np.array(load_img("train/masks/{}.png".format(idx), grayscale=True)) / 255 for idx in tqdm_notebook(train_df.index)]
# Out:
# <ipython-input-10-ea988bf11779>:1: TqdmDeprecationWarning: This function will be removed in tqdm==5.0.0
# Please use `tqdm.notebook.tqdm` instead of `tqdm.tqdm_notebook`
#   train_df["masks"] = [np.array(load_img("train/masks/{}.png".format(idx), grayscale=True)) / 255 for idx in tqdm_notebook(train_df.index)]
# HBox(children=(HTML(value=''), FloatProgress(value=0.0, max=4000.0), HTML(value='')))

# %%
train_df["coverage"] = train_df.masks.map(np.sum) / pow(img_size_ori, 2)

def cov_to_class(val):    
    for i in range(0, 11):
        if val * 10 <= i :
            return i
        
train_df["coverage_class"] = train_df.coverage.map(cov_to_class)

# %%
fig, axs = plt.subplots(1, 2, figsize=(15,5))
sns.distplot(train_df.coverage, kde=False, ax=axs[0])
sns.distplot(train_df.coverage_class, bins=10, kde=False, ax=axs[1])
plt.suptitle("Salt coverage")
axs[0].set_xlabel("Coverage")
axs[1].set_xlabel("Coverage class")
# Out:
# C:\Users\ACER\anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# Text(0.5, 0, 'Coverage class')

# %%
#Plotting the depth distributions¶

sns.distplot(train_df.z, label="Train")
sns.distplot(test_df.z, label="Test")
plt.legend()
plt.title("Depth distribution")
# Out:
# C:\Users\ACER\anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# Text(0.5, 1.0, 'Depth distribution')

# %%
train_df.fillna(0,inplace=True)
depths_df.fillna(0,inplace=True)
test_df.fillna(0,inplace=True)
# Out:
# C:\Users\ACER\anaconda3\lib\site-packages\pandas\core\frame.py:4462: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().fillna(

# %%
# Create train/validation split stratified by salt coverage
ids_train, ids_valid, x_train, x_valid, y_train, y_valid, cov_train, cov_test, depth_train, depth_test = \
train_test_split(train_df.index.values, 
                 np.array(train_df.images.map(upsample).tolist()).reshape(-1, img_size_target, img_size_target, 1),
                 np.array(train_df.masks.map(upsample).tolist()).reshape(-1, img_size_target, img_size_target, 1),
                 train_df.coverage.values, 
                 train_df.z.values, 
                 test_size=0.2, stratify=train_df.coverage_class, random_state=555)

# %%
def BatchActivate(x):
    x = BatchNormalization()(x)
    x = Activation('relu')(x)
    return x

def convolution_block(x, filters, size, strides=(1,1), padding='same', activation=True):
    x = Conv2D(filters, size, strides=strides, padding=padding)(x)
    if activation==True: x = BatchActivate(x)
    return x

def residual_block(blockInput, num_filters=16, batch_activate=False):
    x = BatchActivate(blockInput)
    x = convolution_block(x, num_filters, (3,3))
    x = convolution_block(x, num_filters, (3,3), activation=False)
    x = Add()([x, blockInput])
    if batch_activate: x = BatchActivate(x)
    return x

# %%
# Build Model
def build_model(input_layer, start_neurons, DropoutRatio=0.5):
    # 101 -> 50
    conv1 = Conv2D(start_neurons*1, (3,3), activation=None, padding='same')(input_layer)
    conv1 = residual_block(conv1, start_neurons*1)
    conv1 = residual_block(conv1, start_neurons*1, True)
    pool1 = MaxPooling2D((2,2))(conv1)
    pool1 = Dropout(DropoutRatio/2)(pool1)
    
    # 50 -> 25
    conv2 = Conv2D(start_neurons*2, (3,3), activation=None, padding='same')(pool1)
    conv2 = residual_block(conv2, start_neurons*2)
    conv2 = residual_block(conv2, start_neurons*2, True)
    pool2 = MaxPooling2D((2,2))(conv2)
    pool2 = Dropout(DropoutRatio)(pool2)
    
    # 25 -> 12
    conv3 = Conv2D(start_neurons*4, (3,3), activation=None, padding='same')(pool2)
    conv3 = residual_block(conv3, start_neurons*4)
    conv3 = residual_block(conv3, start_neurons*4, True)
    pool3 = MaxPooling2D((2,2))(conv3)
    pool3 = Dropout(DropoutRatio)(pool3)
    
    # 12 -> 6
    conv4 = Conv2D(start_neurons*8, (3,3), activation=None, padding='same')(pool3)
    conv4 = residual_block(conv4, start_neurons*8)
    conv4 = residual_block(conv4, start_neurons*8, True)
    pool4 = MaxPooling2D((2,2))(conv4)
    pool4 = Dropout(DropoutRatio)(pool4)
    
    # Middle
    convm = Conv2D(start_neurons*16, (3,3), activation=None, padding='same')(pool4)
    convm = residual_block(convm, start_neurons*16)
    convm = residual_block(convm, start_neurons*16, True)
    
    # 6 -> 12
    deconv4 = Conv2DTranspose(start_neurons*8, (3,3), strides=(2,2), padding='same')(convm)
    uconv4 = concatenate([deconv4, conv4])
    uconv4 = Dropout(DropoutRatio)(uconv4)
    
    uconv4 = Conv2D(start_neurons*8, (3,3), activation=None, padding='same')(uconv4)
    uconv4 = residual_block(uconv4, start_neurons*8)
    uconv4 = residual_block(uconv4, start_neurons*8, True)
    
    # 12 -> 25
    deconv3 = Conv2DTranspose(start_neurons*4, (3,3), strides=(2,2), padding='valid')(uconv4)
    uconv3 = concatenate([deconv3, conv3])
    uconv3 = Dropout(DropoutRatio)(uconv3)
    
    uconv3 = Conv2D(start_neurons*4, (3,3), activation=None, padding='same')(uconv3)
    uconv3 = residual_block(uconv3, start_neurons*4)
    uconv3 = residual_block(uconv3, start_neurons*4, True)
    
    # 25 -> 50
    deconv2 = Conv2DTranspose(start_neurons*2, (3,3), strides=(2,2), padding='same')(uconv3)
    uconv2 = concatenate([deconv2, conv2])
    uconv2 = Dropout(DropoutRatio)(uconv2)
    
    uconv2 = Conv2D(start_neurons*2, (3,3), activation=None, padding='same')(uconv2)
    uconv2 = residual_block(uconv2, start_neurons*2)
    uconv2 = residual_block(uconv2, start_neurons*2, True)
    
    # 50 -> 101
    deconv1 = Conv2DTranspose(start_neurons*1, (3,3), strides=(2,2), padding='valid')(uconv2)
    uconv1 = concatenate([deconv1, conv1])
    uconv1 = Dropout(DropoutRatio)(uconv1)
    
    uconv1 = Conv2D(start_neurons*1, (3,3), activation=None, padding='same')(uconv1)
    uconv1 = residual_block(uconv1, start_neurons*1)
    uconv1 = residual_block(uconv1, start_neurons*1, True)
    
    output_layer_noActi = Conv2D(1, (1,1), padding='same', activation=None)(uconv1)
    output_layer = Activation('sigmoid')(output_layer_noActi)
    
    return output_layer

# %%
def get_iou_vector(A, B):
    batch_size = A.shape[0]
    metric = []
    for batch in range(batch_size):
        t, p = A[batch]>0, B[batch]>0
        intersection = np.logical_and(t, p)
        union = np.logical_or(t, p)
        iou = (np.sum(intersection > 0) + 1e-10 )/ (np.sum(union > 0) + 1e-10)
        thresholds = np.arange(0.5, 1, 0.05)
        s = []
        for thresh in thresholds:
            s.append(iou > thresh)
        metric.append(np.mean(s))
        
    return np.mean(metric)

def my_iou_metric(label, pred):
    return tf.numpy_function(get_iou_vector, [label, pred>0.5], tf.float64)

def my_iou_metric_2(label, pred):
    return tf.numpy_function(get_iou_vector, [label, pred >0], tf.float64)

# %%
# code download from: https://github.com/bermanmaxim/LovaszSoftmax
def lovasz_grad(gt_sorted):
    """
    Computes gradient of the Lovasz extension w.r.t sorted errors
    See Alg. 1 in paper
    """
    gts = tf.reduce_sum(gt_sorted)
    intersection = gts - tf.cumsum(gt_sorted)
    union = gts + tf.cumsum(1. - gt_sorted)
    jaccard = 1. - intersection / union
    jaccard = tf.concat((jaccard[0:1], jaccard[1:] - jaccard[:-1]), 0)
    return jaccard

# --------------------------- BINARY LOSSES ---------------------------

def lovasz_hinge(logits, labels, per_image=True, ignore=None):
    """
    Binary Lovasz hinge loss
      logits: [B, H, W] Variable, logits at each pixel (between -\infty and +\infty)
      labels: [B, H, W] Tensor, binary ground truth masks (0 or 1)
      per_image: compute the loss per image instead of per batch
      ignore: void class id
    """
    if per_image:
        def treat_image(log_lab):
            log, lab = log_lab
            log, lab = tf.expand_dims(log, 0), tf.expand_dims(lab, 0)
            log, lab = flatten_binary_scores(log, lab, ignore)
            return lovasz_hinge_flat(log, lab)
        losses = tf.map_fn(treat_image, (logits, labels), dtype=tf.float32)
        loss = tf.reduce_mean(losses)
    else:
        loss = lovasz_hinge_flat(*flatten_binary_scores(logits, labels, ignore))
    return loss

def lovasz_hinge_flat(logits, labels):
    """
    Binary Lovasz hinge loss
      logits: [P] Variable, logits at each prediction (between -\infty and +\infty)
      labels: [P] Tensor, binary ground truth labels (0 or 1)
      ignore: label to ignore
    """

    def compute_loss():
        labelsf = tf.cast(labels, logits.dtype)
        signs = 2. * labelsf - 1.
        errors = 1. - logits * tf.stop_gradient(signs)
        errors_sorted, perm = tf.nn.top_k(errors, k=tf.shape(errors)[0], name="descending_sort")
        gt_sorted = tf.gather(labelsf, perm)
        grad = lovasz_grad(gt_sorted)
        loss = tf.tensordot(tf.nn.elu(errors_sorted), tf.stop_gradient(grad), 1, name="loss_non_void")
        return loss

    # deal with the void prediction case (only void pixels)
    loss = tf.cond(tf.equal(tf.shape(logits)[0], 0),
                   lambda: tf.reduce_sum(logits) * 0.,
                   compute_loss,
                   strict=True,
                   name="loss"
                   )
    return loss


def flatten_binary_scores(scores, labels, ignore=None):
    """
    Flattens predictions in the batch (binary case)
    Remove labels equal to 'ignore'
    """
    scores = tf.reshape(scores, (-1,))
    labels = tf.reshape(labels, (-1,))
    if ignore is None:
        return scores, labels
    valid = tf.not_equal(labels, ignore)
    vscores = tf.boolean_mask(scores, valid, name='valid_scores')
    vlabels = tf.boolean_mask(labels, valid, name='valid_labels')
    return vscores, vlabels

def lovasz_loss(y_true, y_pred):
    y_true, y_pred = K.cast(K.squeeze(y_true, -1), 'int32'), K.cast(K.squeeze(y_pred, -1), 'float32')
    #logits = K.log(y_pred / (1. - y_pred))
    logits = y_pred #Jiaxin
    loss = lovasz_hinge(logits, y_true, per_image = True, ignore = None)
    return loss

# %%
#Data augmentation
x_train = np.append(x_train, [np.fliplr(x) for x in x_train], axis=0)
y_train = np.append(y_train, [np.fliplr(x) for x in y_train], axis=0)
print(x_train.shape)
print(y_valid.shape)
# Out:
# (6400, 101, 101, 1)
# (800, 101, 101, 1)

# %%
# model
input_layer = Input((img_size_target, img_size_target, 1))
output_layer = build_model(input_layer, 16,0.5)

model1 = Model(input_layer, output_layer)

c = tf.optimizers.Adam(lr = 0.005)
model1.compile(loss="binary_crossentropy", optimizer=c, metrics=[my_iou_metric])

model1.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_8 (InputLayer)           [(None, 101, 101, 1  0           []
#                                 )]
#
#  conv2d_175 (Conv2D)            (None, 101, 101, 16  160         ['input_8[0][0]']
#                                 )
#
#  batch_normalization_175 (Batch  (None, 101, 101, 16  64         ['conv2d_175[0][0]']
#  Normalization)                 )
#
#  activation_175 (Activation)    (None, 101, 101, 16  0           ['batch_normalization_175[0][0]']
#                                 )
#
#  conv2d_176 (Conv2D)            (None, 101, 101, 16  2320        ['activation_175[0][0]']
#                                 )
#
#  batch_normalization_176 (Batch  (None, 101, 101, 16  64         ['conv2d_176[0][0]']
#  Normalization)                 )
#
#  activation_176 (Activation)    (None, 101, 101, 16  0           ['batch_normalization_176[0][0]']
#                                 )
#
#  conv2d_177 (Conv2D)            (None, 101, 101, 16  2320        ['activation_176[0][0]']
#                                 )
#
#  add_70 (Add)                   (None, 101, 101, 16  0           ['conv2d_177[0][0]',
#                                 )                                 'conv2d_175[0][0]']
#
#  batch_normalization_177 (Batch  (None, 101, 101, 16  64         ['add_70[0][0]']
#  Normalization)                 )
#
#  activation_177 (Activation)    (None, 101, 101, 16  0           ['batch_normalization_177[0][0]']
#                                 )
#
#  conv2d_178 (Conv2D)            (None, 101, 101, 16  2320        ['activation_177[0][0]']
#                                 )
#
#  batch_normalization_178 (Batch  (None, 101, 101, 16  64         ['conv2d_178[0][0]']
#  Normalization)                 )
#
#  activation_178 (Activation)    (None, 101, 101, 16  0           ['batch_normalization_178[0][0]']
#                                 )
#
#  conv2d_179 (Conv2D)            (None, 101, 101, 16  2320        ['activation_178[0][0]']
#                                 )
#
#  add_71 (Add)                   (None, 101, 101, 16  0           ['conv2d_179[0][0]',
#                                 )                                 'add_70[0][0]']
#
#  batch_normalization_179 (Batch  (None, 101, 101, 16  64         ['add_71[0][0]']
#  Normalization)                 )
#
#  activation_179 (Activation)    (None, 101, 101, 16  0           ['batch_normalization_179[0][0]']
#                                 )
#
#  max_pooling2d_28 (MaxPooling2D  (None, 50, 50, 16)  0           ['activation_179[0][0]']
#  )
#
#  dropout_28 (Dropout)           (None, 50, 50, 16)   0           ['max_pooling2d_28[0][0]']
#
#  conv2d_180 (Conv2D)            (None, 50, 50, 32)   4640        ['dropout_28[0][0]']
#
#  batch_normalization_180 (Batch  (None, 50, 50, 32)  128         ['conv2d_180[0][0]']
#  Normalization)
#
#  activation_180 (Activation)    (None, 50, 50, 32)   0           ['batch_normalization_180[0][0]']
#
#  conv2d_181 (Conv2D)            (None, 50, 50, 32)   9248        ['activation_180[0][0]']
#
#  batch_normalization_181 (Batch  (None, 50, 50, 32)  128         ['conv2d_181[0][0]']
#  Normalization)
#
#  activation_181 (Activation)    (None, 50, 50, 32)   0           ['batch_normalization_181[0][0]']
#
#  conv2d_182 (Conv2D)            (None, 50, 50, 32)   9248        ['activation_181[0][0]']
#
#  add_72 (Add)                   (None, 50, 50, 32)   0           ['conv2d_182[0][0]',
#                                                                   'conv2d_180[0][0]']
#
#  batch_normalization_182 (Batch  (None, 50, 50, 32)  128         ['add_72[0][0]']
#  Normalization)
#
#  activation_182 (Activation)    (None, 50, 50, 32)   0           ['batch_normalization_182[0][0]']
#
#  conv2d_183 (Conv2D)            (None, 50, 50, 32)   9248        ['activation_182[0][0]']
#
#  batch_normalization_183 (Batch  (None, 50, 50, 32)  128         ['conv2d_183[0][0]']
#  Normalization)
#
#  activation_183 (Activation)    (None, 50, 50, 32)   0           ['batch_normalization_183[0][0]']
#
#  conv2d_184 (Conv2D)            (None, 50, 50, 32)   9248        ['activation_183[0][0]']
#
#  add_73 (Add)                   (None, 50, 50, 32)   0           ['conv2d_184[0][0]',
#                                                                   'add_72[0][0]']
# C:\Users\ACER\anaconda3\lib\site-packages\keras\optimizers\optimizer_v2\adam.py:110: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super(Adam, self).__init__(name, **kwargs)
#  batch_normalization_184 (Batch  (None, 50, 50, 32)  128         ['add_73[0][0]']
#  Normalization)
#
#  activation_184 (Activation)    (None, 50, 50, 32)   0           ['batch_normalization_184[0][0]']
#
#  max_pooling2d_29 (MaxPooling2D  (None, 25, 25, 32)  0           ['activation_184[0][0]']
#  )
#
#  dropout_29 (Dropout)           (None, 25, 25, 32)   0           ['max_pooling2d_29[0][0]']
#
#  conv2d_185 (Conv2D)            (None, 25, 25, 64)   18496       ['dropout_29[0][0]']
#
#  batch_normalization_185 (Batch  (None, 25, 25, 64)  256         ['conv2d_185[0][0]']
#  Normalization)
#
#  activation_185 (Activation)    (None, 25, 25, 64)   0           ['batch_normalization_185[0][0]']
#
#  conv2d_186 (Conv2D)            (None, 25, 25, 64)   36928       ['activation_185[0][0]']
#
#  batch_normalization_186 (Batch  (None, 25, 25, 64)  256         ['conv2d_186[0][0]']
#  Normalization)
#
#  activation_186 (Activation)    (None, 25, 25, 64)   0           ['batch_normalization_186[0][0]']
#
#  conv2d_187 (Conv2D)            (None, 25, 25, 64)   36928       ['activation_186[0][0]']
#
#  add_74 (Add)                   (None, 25, 25, 64)   0           ['conv2d_187[0][0]',
#                                                                   'conv2d_185[0][0]']
#
#  batch_normalization_187 (Batch  (None, 25, 25, 64)  256         ['add_74[0][0]']
#  Normalization)
#
#  activation_187 (Activation)    (None, 25, 25, 64)   0           ['batch_normalization_187[0][0]']
#
#  conv2d_188 (Conv2D)            (None, 25, 25, 64)   36928       ['activation_187[0][0]']
#
#  batch_normalization_188 (Batch  (None, 25, 25, 64)  256         ['conv2d_188[0][0]']
#  Normalization)
#
#  activation_188 (Activation)    (None, 25, 25, 64)   0           ['batch_normalization_188[0][0]']
#
#  conv2d_189 (Conv2D)            (None, 25, 25, 64)   36928       ['activation_188[0][0]']
#
#  add_75 (Add)                   (None, 25, 25, 64)   0           ['conv2d_189[0][0]',
#                                                                   'add_74[0][0]']
#
#  batch_normalization_189 (Batch  (None, 25, 25, 64)  256         ['add_75[0][0]']
#  Normalization)
#
#  activation_189 (Activation)    (None, 25, 25, 64)   0           ['batch_normalization_189[0][0]']
#
#  max_pooling2d_30 (MaxPooling2D  (None, 12, 12, 64)  0           ['activation_189[0][0]']
#  )
#
#  dropout_30 (Dropout)           (None, 12, 12, 64)   0           ['max_pooling2d_30[0][0]']
#
#  conv2d_190 (Conv2D)            (None, 12, 12, 128)  73856       ['dropout_30[0][0]']
#
#  batch_normalization_190 (Batch  (None, 12, 12, 128)  512        ['conv2d_190[0][0]']
#  Normalization)
#
#  activation_190 (Activation)    (None, 12, 12, 128)  0           ['batch_normalization_190[0][0]']
#
#  conv2d_191 (Conv2D)            (None, 12, 12, 128)  147584      ['activation_190[0][0]']
#
#  batch_normalization_191 (Batch  (None, 12, 12, 128)  512        ['conv2d_191[0][0]']
#  Normalization)
#
#  activation_191 (Activation)    (None, 12, 12, 128)  0           ['batch_normalization_191[0][0]']
#
#  conv2d_192 (Conv2D)            (None, 12, 12, 128)  147584      ['activation_191[0][0]']
#
#  add_76 (Add)                   (None, 12, 12, 128)  0           ['conv2d_192[0][0]',
#                                                                   'conv2d_190[0][0]']
#
#  batch_normalization_192 (Batch  (None, 12, 12, 128)  512        ['add_76[0][0]']
#  Normalization)
#
#  activation_192 (Activation)    (None, 12, 12, 128)  0           ['batch_normalization_192[0][0]']
#
#  conv2d_193 (Conv2D)            (None, 12, 12, 128)  147584      ['activation_192[0][0]']
#
#  batch_normalization_193 (Batch  (None, 12, 12, 128)  512        ['conv2d_193[0][0]']
#  Normalization)
#
#  activation_193 (Activation)    (None, 12, 12, 128)  0           ['batch_normalization_193[0][0]']
#
#  conv2d_194 (Conv2D)            (None, 12, 12, 128)  147584      ['activation_193[0][0]']
#
#  add_77 (Add)                   (None, 12, 12, 128)  0           ['conv2d_194[0][0]',
#                                                                   'add_76[0][0]']
#
#  batch_normalization_194 (Batch  (None, 12, 12, 128)  512        ['add_77[0][0]']
#  Normalization)
#
#  activation_194 (Activation)    (None, 12, 12, 128)  0           ['batch_normalization_194[0][0]']
#
#  max_pooling2d_31 (MaxPooling2D  (None, 6, 6, 128)   0           ['activation_194[0][0]']
#  )
#
#  dropout_31 (Dropout)           (None, 6, 6, 128)    0           ['max_pooling2d_31[0][0]']
#
#  conv2d_195 (Conv2D)            (None, 6, 6, 256)    295168      ['dropout_31[0][0]']
#
#  batch_normalization_195 (Batch  (None, 6, 6, 256)   1024        ['conv2d_195[0][0]']
#  Normalization)
#
#  activation_195 (Activation)    (None, 6, 6, 256)    0           ['batch_normalization_195[0][0]']
#
#  conv2d_196 (Conv2D)            (None, 6, 6, 256)    590080      ['activation_195[0][0]']
#
#  batch_normalization_196 (Batch  (None, 6, 6, 256)   1024        ['conv2d_196[0][0]']
#  Normalization)
#
#  activation_196 (Activation)    (None, 6, 6, 256)    0           ['batch_normalization_196[0][0]']
#
#  conv2d_197 (Conv2D)            (None, 6, 6, 256)    590080      ['activation_196[0][0]']
#
#  add_78 (Add)                   (None, 6, 6, 256)    0           ['conv2d_197[0][0]',
#                                                                   'conv2d_195[0][0]']
#
#  batch_normalization_197 (Batch  (None, 6, 6, 256)   1024        ['add_78[0][0]']
#  Normalization)
#
#  activation_197 (Activation)    (None, 6, 6, 256)    0           ['batch_normalization_197[0][0]']
#
#  conv2d_198 (Conv2D)            (None, 6, 6, 256)    590080      ['activation_197[0][0]']
#
#  batch_normalization_198 (Batch  (None, 6, 6, 256)   1024        ['conv2d_198[0][0]']
#  Normalization)
#
#  activation_198 (Activation)    (None, 6, 6, 256)    0           ['batch_normalization_198[0][0]']
#
#  conv2d_199 (Conv2D)            (None, 6, 6, 256)    590080      ['activation_198[0][0]']
#
#  add_79 (Add)                   (None, 6, 6, 256)    0           ['conv2d_199[0][0]',
#                                                                   'add_78[0][0]']
#
#  batch_normalization_199 (Batch  (None, 6, 6, 256)   1024        ['add_79[0][0]']
#  Normalization)
#
#  activation_199 (Activation)    (None, 6, 6, 256)    0           ['batch_normalization_199[0][0]']
#
#  conv2d_transpose_7 (Conv2DTran  (None, 12, 12, 128)  295040     ['activation_199[0][0]']
#  spose)
#
#  concatenate (Concatenate)      (None, 12, 12, 256)  0           ['conv2d_transpose_7[0][0]',
#                                                                   'activation_194[0][0]']
#
#  dropout_32 (Dropout)           (None, 12, 12, 256)  0           ['concatenate[0][0]']
#
#  conv2d_200 (Conv2D)            (None, 12, 12, 128)  295040      ['dropout_32[0][0]']
#
#  batch_normalization_200 (Batch  (None, 12, 12, 128)  512        ['conv2d_200[0][0]']
#  Normalization)
#
#  activation_200 (Activation)    (None, 12, 12, 128)  0           ['batch_normalization_200[0][0]']
#
#  conv2d_201 (Conv2D)            (None, 12, 12, 128)  147584      ['activation_200[0][0]']
#
#  batch_normalization_201 (Batch  (None, 12, 12, 128)  512        ['conv2d_201[0][0]']
#  Normalization)
#
#  activation_201 (Activation)    (None, 12, 12, 128)  0           ['batch_normalization_201[0][0]']
#
#  conv2d_202 (Conv2D)            (None, 12, 12, 128)  147584      ['activation_201[0][0]']
#
#  add_80 (Add)                   (None, 12, 12, 128)  0           ['conv2d_202[0][0]',
#                                                                   'conv2d_200[0][0]']
#
#  batch_normalization_202 (Batch  (None, 12, 12, 128)  512        ['add_80[0][0]']
#  Normalization)
#
#  activation_202 (Activation)    (None, 12, 12, 128)  0           ['batch_normalization_202[0][0]']
#
#  conv2d_203 (Conv2D)            (None, 12, 12, 128)  147584      ['activation_202[0][0]']
#
#  batch_normalization_203 (Batch  (None, 12, 12, 128)  512        ['conv2d_203[0][0]']
#  Normalization)
#
#  activation_203 (Activation)    (None, 12, 12, 128)  0           ['batch_normalization_203[0][0]']
#
#  conv2d_204 (Conv2D)            (None, 12, 12, 128)  147584      ['activation_203[0][0]']
#
#  add_81 (Add)                   (None, 12, 12, 128)  0           ['conv2d_204[0][0]',
#                                                                   'add_80[0][0]']
#
#  batch_normalization_204 (Batch  (None, 12, 12, 128)  512        ['add_81[0][0]']
#  Normalization)
#
#  activation_204 (Activation)    (None, 12, 12, 128)  0           ['batch_normalization_204[0][0]']
#
#  conv2d_transpose_8 (Conv2DTran  (None, 25, 25, 64)  73792       ['activation_204[0][0]']
#  spose)
#
#  concatenate_1 (Concatenate)    (None, 25, 25, 128)  0           ['conv2d_transpose_8[0][0]',
#                                                                   'activation_189[0][0]']
#
#  dropout_33 (Dropout)           (None, 25, 25, 128)  0           ['concatenate_1[0][0]']
#
#  conv2d_205 (Conv2D)            (None, 25, 25, 64)   73792       ['dropout_33[0][0]']
#
#  batch_normalization_205 (Batch  (None, 25, 25, 64)  256         ['conv2d_205[0][0]']
#  Normalization)
#
#  activation_205 (Activation)    (None, 25, 25, 64)   0           ['batch_normalization_205[0][0]']
#
#  conv2d_206 (Conv2D)            (None, 25, 25, 64)   36928       ['activation_205[0][0]']
#
#  batch_normalization_206 (Batch  (None, 25, 25, 64)  256         ['conv2d_206[0][0]']
#  Normalization)
#
#  activation_206 (Activation)    (None, 25, 25, 64)   0           ['batch_normalization_206[0][0]']
#
#  conv2d_207 (Conv2D)            (None, 25, 25, 64)   36928       ['activation_206[0][0]']
#
#  add_82 (Add)                   (None, 25, 25, 64)   0           ['conv2d_207[0][0]',
#                                                                   'conv2d_205[0][0]']
#
#  batch_normalization_207 (Batch  (None, 25, 25, 64)  256         ['add_82[0][0]']
#  Normalization)
#
#  activation_207 (Activation)    (None, 25, 25, 64)   0           ['batch_normalization_207[0][0]']
#
#  conv2d_208 (Conv2D)            (None, 25, 25, 64)   36928       ['activation_207[0][0]']
#
#  batch_normalization_208 (Batch  (None, 25, 25, 64)  256         ['conv2d_208[0][0]']
#  Normalization)
#
#  activation_208 (Activation)    (None, 25, 25, 64)   0           ['batch_normalization_208[0][0]']
#
#  conv2d_209 (Conv2D)            (None, 25, 25, 64)   36928       ['activation_208[0][0]']
#
#  add_83 (Add)                   (None, 25, 25, 64)   0           ['conv2d_209[0][0]',
#                                                                   'add_82[0][0]']
#
#  batch_normalization_209 (Batch  (None, 25, 25, 64)  256         ['add_83[0][0]']
#  Normalization)
#
#  activation_209 (Activation)    (None, 25, 25, 64)   0           ['batch_normalization_209[0][0]']
#
#  conv2d_transpose_9 (Conv2DTran  (None, 50, 50, 32)  18464       ['activation_209[0][0]']
#  spose)
#
#  concatenate_2 (Concatenate)    (None, 50, 50, 64)   0           ['conv2d_transpose_9[0][0]',
#                                                                   'activation_184[0][0]']
#
#  dropout_34 (Dropout)           (None, 50, 50, 64)   0           ['concatenate_2[0][0]']
#
#  conv2d_210 (Conv2D)            (None, 50, 50, 32)   18464       ['dropout_34[0][0]']
#
#  batch_normalization_210 (Batch  (None, 50, 50, 32)  128         ['conv2d_210[0][0]']
#  Normalization)
#
#  activation_210 (Activation)    (None, 50, 50, 32)   0           ['batch_normalization_210[0][0]']
#
#  conv2d_211 (Conv2D)            (None, 50, 50, 32)   9248        ['activation_210[0][0]']
#
#  batch_normalization_211 (Batch  (None, 50, 50, 32)  128         ['conv2d_211[0][0]']
#  Normalization)
#
#  activation_211 (Activation)    (None, 50, 50, 32)   0           ['batch_normalization_211[0][0]']
#
#  conv2d_212 (Conv2D)            (None, 50, 50, 32)   9248        ['activation_211[0][0]']
#
#  add_84 (Add)                   (None, 50, 50, 32)   0           ['conv2d_212[0][0]',
#                                                                   'conv2d_210[0][0]']
#
#  batch_normalization_212 (Batch  (None, 50, 50, 32)  128         ['add_84[0][0]']
#  Normalization)
#
#  activation_212 (Activation)    (None, 50, 50, 32)   0           ['batch_normalization_212[0][0]']
#
#  conv2d_213 (Conv2D)            (None, 50, 50, 32)   9248        ['activation_212[0][0]']
#
#  batch_normalization_213 (Batch  (None, 50, 50, 32)  128         ['conv2d_213[0][0]']
#  Normalization)
#
#  activation_213 (Activation)    (None, 50, 50, 32)   0           ['batch_normalization_213[0][0]']
#
#  conv2d_214 (Conv2D)            (None, 50, 50, 32)   9248        ['activation_213[0][0]']
#
#  add_85 (Add)                   (None, 50, 50, 32)   0           ['conv2d_214[0][0]',
#                                                                   'add_84[0][0]']
#
#  batch_normalization_214 (Batch  (None, 50, 50, 32)  128         ['add_85[0][0]']
#  Normalization)
#
#  activation_214 (Activation)    (None, 50, 50, 32)   0           ['batch_normalization_214[0][0]']
#
#  conv2d_transpose_10 (Conv2DTra  (None, 101, 101, 16  4624       ['activation_214[0][0]']
#  nspose)                        )
#
#  concatenate_3 (Concatenate)    (None, 101, 101, 32  0           ['conv2d_transpose_10[0][0]',
#                                 )                                 'activation_179[0][0]']
#
#  dropout_35 (Dropout)           (None, 101, 101, 32  0           ['concatenate_3[0][0]']
#                                 )
#
#  conv2d_215 (Conv2D)            (None, 101, 101, 16  4624        ['dropout_35[0][0]']
#                                 )
#
#  batch_normalization_215 (Batch  (None, 101, 101, 16  64         ['conv2d_215[0][0]']
#  Normalization)                 )
#
#  activation_215 (Activation)    (None, 101, 101, 16  0           ['batch_normalization_215[0][0]']
#                                 )
#
#  conv2d_216 (Conv2D)            (None, 101, 101, 16  2320        ['activation_215[0][0]']
#                                 )
#
#  batch_normalization_216 (Batch  (None, 101, 101, 16  64         ['conv2d_216[0][0]']
#  Normalization)                 )
#
#  activation_216 (Activation)    (None, 101, 101, 16  0           ['batch_normalization_216[0][0]']
#                                 )
#
#  conv2d_217 (Conv2D)            (None, 101, 101, 16  2320        ['activation_216[0][0]']
#                                 )
#
#  add_86 (Add)                   (None, 101, 101, 16  0           ['conv2d_217[0][0]',
#                                 )                                 'conv2d_215[0][0]']
#
#  batch_normalization_217 (Batch  (None, 101, 101, 16  64         ['add_86[0][0]']
#  Normalization)                 )
#
#  activation_217 (Activation)    (None, 101, 101, 16  0           ['batch_normalization_217[0][0]']
#                                 )
#
#  conv2d_218 (Conv2D)            (None, 101, 101, 16  2320        ['activation_217[0][0]']
#                                 )
#
#  batch_normalization_218 (Batch  (None, 101, 101, 16  64         ['conv2d_218[0][0]']
#  Normalization)                 )
#
#  activation_218 (Activation)    (None, 101, 101, 16  0           ['batch_normalization_218[0][0]']
#                                 )
#
#  conv2d_219 (Conv2D)            (None, 101, 101, 16  2320        ['activation_218[0][0]']
#                                 )
#
#  add_87 (Add)                   (None, 101, 101, 16  0           ['conv2d_219[0][0]',
#                                 )                                 'add_86[0][0]']
#
#  batch_normalization_219 (Batch  (None, 101, 101, 16  64         ['add_87[0][0]']
#  Normalization)                 )
#
#  activation_219 (Activation)    (None, 101, 101, 16  0           ['batch_normalization_219[0][0]']
#                                 )
#
#  conv2d_220 (Conv2D)            (None, 101, 101, 1)  17          ['activation_219[0][0]']
#
#  activation_220 (Activation)    (None, 101, 101, 1)  0           ['conv2d_220[0][0]']
#
# ==================================================================================================
# Total params: 5,119,857
# Trainable params: 5,112,497
# Non-trainable params: 7,360
# __________________________________________________________________________________________________

# %%
early_stopping = EarlyStopping(monitor='val_my_iou_metric', mode = 'max',patience=15, verbose=1)
model_checkpoint = ModelCheckpoint(save_model_name, monitor='my_iou_metric', mode='max',
                                   save_best_only=True, verbose=1)

reduce_lr = ReduceLROnPlateau(monitor='val_my_iou_metric', mode='max', factor=0.5, patience=5,
                              min_lr=0.0001, verbose=1)

epochs = 100
batch_size = 128

t_model1_start = time.time()
history = model1.fit(x_train, y_train,
                     validation_data = [x_valid, y_valid], 
                     epochs = epochs, 
                     batch_size = batch_size, 
                     callbacks = [early_stopping, model_checkpoint, reduce_lr],
                     verbose = 2)
t_model1_end = time.time()
print(f"Run time = {(t_model1_end-t_model1_start)/3600} hours")
# Out:
# Epoch 1/100
#
# Epoch 1: my_iou_metric improved from -inf to 0.13177, saving model to Unet_resnet_v5.model
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op while saving (showing 5 of 50). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: Unet_resnet_v5.model\assets
# INFO:tensorflow:Assets written to: Unet_resnet_v5.model\assets
# 50/50 - 3017s - loss: -4.8558e+02 - my_iou_metric: 0.1318 - val_loss: 2062.3635 - val_my_iou_metric: 0.0000e+00 - lr: 0.0050 - 3017s/epoch - 60s/step
# Epoch 2/100
#
# Epoch 2: my_iou_metric improved from 0.13177 to 0.13463, saving model to Unet_resnet_v5.model
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op while saving (showing 5 of 50). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: Unet_resnet_v5.model\assets
# INFO:tensorflow:Assets written to: Unet_resnet_v5.model\assets
# 50/50 - 4005s - loss: -1.2228e+03 - my_iou_metric: 0.1346 - val_loss: -9.3008e+02 - val_my_iou_metric: 0.1339 - lr: 0.0050 - 4005s/epoch - 80s/step
# Epoch 3/100
#
# Epoch 3: my_iou_metric did not improve from 0.13463
# 50/50 - 3488s - loss: -2.5573e+03 - my_iou_metric: 0.1326 - val_loss: -1.5979e+05 - val_my_iou_metric: 0.1128 - lr: 0.0050 - 3488s/epoch - 70s/step
# Epoch 4/100
#
# Epoch 4: my_iou_metric did not improve from 0.13463
# 50/50 - 3724s - loss: -4.5367e+03 - my_iou_metric: 0.1326 - val_loss: -6.4279e+04 - val_my_iou_metric: 0.1266 - lr: 0.0050 - 3724s/epoch - 74s/step
# Epoch 5/100
#
# Epoch 5: my_iou_metric did not improve from 0.13463
# 50/50 - 4678s - loss: -7.2991e+03 - my_iou_metric: 0.1326 - val_loss: -2.5764e+04 - val_my_iou_metric: 0.1339 - lr: 0.0050 - 4678s/epoch - 94s/step
# Epoch 6/100
#
# Epoch 6: my_iou_metric did not improve from 0.13463
# 50/50 - 5984s - loss: -1.0675e+04 - my_iou_metric: 0.1326 - val_loss: -2.3428e+03 - val_my_iou_metric: 0.1339 - lr: 0.0050 - 5984s/epoch - 120s/step
# Epoch 7/100

# %% [markdown]
# ### Sorry, for ResNet by using a lot of pictures my laptop is not strong enough. Can only run until Epoch 7/100 after 1 day 2 nights, then turns itself off. For the bottom part, I took a Screen Shoot from Kaggle so I can find out the output.

# %%
model1 = load_model(save_model_name, custom_objects={'my_iou_metric':my_iou_metric})
# remove activation layer and use lovasz loss
input_x = model1.layers[0].input

output_layer = model1.layers[-1].input
model = Model(input_x, output_layer)
c = optimizers.adam(lr=0.01)

model.compile(loss=lovasz_loss, optimizer=c, metrics=[my_iou_metric_2])

model.summary()

# %% [markdown]
# ![ff.png](data:image/png;base64,...)

# %%
early_stopping = EarlyStopping(monitor='val_my_iou_metric_2', mode = 'max',patience=30, verbose=1)
model_checkpoint = ModelCheckpoint(save_model_name,monitor='val_my_iou_metric_2', 
                                   mode = 'max', save_best_only=True, verbose=1)
reduce_lr = ReduceLROnPlateau(monitor='val_my_iou_metric_2', mode = 'max',factor=0.5, patience=5, 
                              min_lr=0.00005, verbose=1)
epochs = 120
batch_size = 64

t_model2_start = time.time()
history = model.fit(x_train, y_train,
                    validation_data=[x_valid, y_valid], 
                    epochs=epochs,
                    batch_size=batch_size,
                    callbacks=[ model_checkpoint,reduce_lr,early_stopping], 
                    verbose=2)
t_model2_end = time.time()
print(f"Run time = {(t_model2_end-t_model2_start)/3600} hours")

# %% [markdown]
# ![zz.png](data:image/png;base64,...)

# %%
fig, (ax_loss, ax_score) = plt.subplots(1, 2, figsize=(15,5))
ax_loss.plot(history.epoch, history.history["loss"], label="Train loss")
ax_loss.plot(history.epoch, history.history["val_loss"], label="Validation loss")
ax_loss.legend()
ax_score.plot(history.epoch, history.history["my_iou_metric_2"], label="Train score")
ax_score.plot(history.epoch, history.history["val_my_iou_metric_2"], label="Validation score")
ax_score.legend()

# %% [markdown]
# ![jj.png](data:image/png;base64,...)

# %%
model = load_model(save_model_name,custom_objects={'my_iou_metric_2': my_iou_metric_2,
                                                   'lovasz_loss': lovasz_loss})

# %%
def predict_result(model,x_test,img_size_target): # predict both orginal and reflect x
    x_test_reflect =  np.array([np.fliplr(x) for x in x_test])
    preds_test = model.predict(x_test).reshape(-1, img_size_target, img_size_target)
    preds_test2_refect = model.predict(x_test_reflect).reshape(-1, img_size_target, img_size_target)
    preds_test += np.array([ np.fliplr(x) for x in preds_test2_refect] )
    return preds_test/2

# %%
preds_valid = predict_result(model,x_valid,img_size_target)

# %%
#Score the model and do a threshold optimization by the best IoU.

# src: https://www.kaggle.com/aglotero/another-iou-metric
def iou_metric(y_true_in, y_pred_in, print_table=False):
    labels = y_true_in
    y_pred = y_pred_in


    true_objects = 2
    pred_objects = 2

    #  if all zeros, original code  generate wrong  bins [-0.5 0 0.5],
    temp1 = np.histogram2d(labels.flatten(), y_pred.flatten(), bins=([0,0.5,1], [0,0.5, 1]))
#     temp1 = np.histogram2d(labels.flatten(), y_pred.flatten(), bins=(true_objects, pred_objects))
    #print(temp1)
    intersection = temp1[0]
    #print("temp2 = ",temp1[1])
    #print(intersection.shape)
   # print(intersection)
    # Compute areas (needed for finding the union between all objects)
    #print(np.histogram(labels, bins = true_objects))
    area_true = np.histogram(labels,bins=[0,0.5,1])[0]
    #print("area_true = ",area_true)
    area_pred = np.histogram(y_pred, bins=[0,0.5,1])[0]
    area_true = np.expand_dims(area_true, -1)
    area_pred = np.expand_dims(area_pred, 0)

    # Compute union
    union = area_true + area_pred - intersection
  
    # Exclude background from the analysis
    intersection = intersection[1:,1:]
    intersection[intersection == 0] = 1e-9
    
    union = union[1:,1:]
    union[union == 0] = 1e-9

    # Compute the intersection over union
    iou = intersection / union
    # Precision helper function
    def precision_at(threshold, iou):
        matches = iou > threshold
        true_positives = np.sum(matches, axis=1) == 1   # Correct objects
        false_positives = np.sum(matches, axis=0) == 0  # Missed objects
        false_negatives = np.sum(matches, axis=1) == 0  # Extra objects
        tp, fp, fn = np.sum(true_positives), np.sum(false_positives), np.sum(false_negatives)
        return tp, fp, fn

    # Loop over IoU thresholds
    prec = []
    if print_table:
        print("Thresh\tTP\tFP\tFN\tPrec.")
    for t in np.arange(0.5, 1.0, 0.05):
        tp, fp, fn = precision_at(t, iou)
        if (tp + fp + fn) > 0:
            p = tp / (tp + fp + fn)
        else:
            p = 0
        if print_table:
            print("{:1.3f}\t{}\t{}\t{}\t{:1.3f}".format(t, tp, fp, fn, p))
        prec.append(p)
        
    if print_table:
        print("AP\t-\t-\t-\t{:1.3f}".format(np.mean(prec)))
    return np.mean(prec)

def iou_metric_batch(y_true_in, y_pred_in):
    batch_size = y_true_in.shape[0]
    metric = []
    for batch in range(batch_size):
        value = iou_metric(y_true_in[batch], y_pred_in[batch])
        metric.append(value)
    return np.mean(metric)

# %%
## Scoring for last model, choose threshold by validation data 
thresholds_ori = np.linspace(0.3, 0.7, 31)
# Reverse sigmoid function: Use code below because the  sigmoid activation was removed
thresholds = np.log(thresholds_ori/(1-thresholds_ori)) 

# ious = np.array([get_iou_vector(y_valid, preds_valid > threshold) for threshold in tqdm_notebook(thresholds)])
# print(ious)
ious = np.array([iou_metric_batch(y_valid, preds_valid > threshold) for threshold in tqdm_notebook(thresholds)])
print(ious)

# %% [markdown]
# ![aaa.png](data:image/png;base64,...)

# %%
threshold_best_index = np.argmax(ious)
iou_best = ious[threshold_best_index]
threshold_best = thresholds[threshold_best_index]

plt.plot(thresholds, ious)
plt.plot(threshold_best, iou_best, 'xr', label='Best threshold')
plt.xlabel("Threshold")
plt.ylabel("IoU")
plt.title("Threshold vs IoU ({}, {})".format(threshold_best, iou_best))
plt.legend()

# %% [markdown]
# ![jn.png](data:image/png;base64,...)

# %%
def rle_encode(im):
    '''
    im: numpy array, 1-mask, 0-background
    Returns run length as string
    '''
    pixels = im.flatten(order='F')
    pixels = np.concatenate([[0], pixels, [0]])
    runs = np.where(pixels[1:] != pixels[:-1])[0] + 1
    runs[1::2] -= runs[::2]
    return ' '.join(str(x) for x in runs)

# %%
x_test = np.array([(np.array(load_img("../input/test/images/{}.png".format(idx), grayscale = True))) / 255 for idx in tqdm_notebook(test_df.index)]).reshape(-1, img_size_target, img_size_target, 1)

# %%
preds_test = predict_result(model,x_test,img_size_target)

# %%
pred_dict = {idx: rle_encode(np.round(downsample(preds_test[i]) > threshold_best)) for i, idx in enumerate(tqdm_notebook(test_df.index.values))}

# %%
sub = pd.DataFrame.from_dict(pred_dict,orient='index')
sub.index.names = ['id']
sub.columns = ['rle_mask']
sub.to_csv(submission_file)

# %%
t_finish = time.time()
print(f"Kernel run time = {(t_finish-t_start)/3600} hours")

# %% [markdown]
# ![hhh.png](data:image/png;base64,...)
